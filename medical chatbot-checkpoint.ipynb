# %% [markdown]
# # INTRODUCTION TO OUR DATASET:
# we have two dataset one is sympton to disease and another one is doctor list according to disease .
# we will find some details about this two dataset and after converting categorical data to numerical
# data then we will visualise the data using this two libraries matplotlib and seaborn.

# %% [markdown]
# # read the dataset

# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\PRAJES DAS\\Downloads\\Symptom2Disease.csv")
df.head()
# Out:
#    Unnamed: 0      label                                               text  \
# 0           0  Psoriasis  I have been experiencing a skin rash on my arm...
# 1           1  Psoriasis  My skin has been peeling, especially on my kne...
# 2           2  Psoriasis  I have been experiencing joint pain in my fing...
# 3           3  Psoriasis  There is a silver like dusting on my skin, esp...
# 4           4  Psoriasis  My nails have small dents or pits in them, and...
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.drop(columns=['Unnamed: 3','Unnamed: 4'],axis=1,inplace=True)

# %%
df
# Out:
#       Unnamed: 0      label                                               text
# 0              0  Psoriasis  I have been experiencing a skin rash on my arm...
# 1              1  Psoriasis  My skin has been peeling, especially on my kne...
# 2              2  Psoriasis  I have been experiencing joint pain in my fing...
# 3              3  Psoriasis  There is a silver like dusting on my skin, esp...
# 4              4  Psoriasis  My nails have small dents or pits in them, and...
# ...          ...        ...                                                ...
# 1194         295   diabetes  I'm shaking and trembling all over. I've lost ...
# 1195         296   diabetes  Particularly in the crevices of my skin, I hav...
# 1196         297   diabetes  I regularly experience these intense urges and...
# 1197         298   diabetes  I have trouble breathing, especially outside. ...
# 1198         299   diabetes  I constantly sneeze and have a dry cough. My i...
#
# [1199 rows x 3 columns]

# %% [markdown]
# # importing all the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %% [markdown]
# # checking the shape of the dataset

# %%
df.shape
# Out:
# (1199, 3)

# %% [markdown]
# # cheching the ststistices of the dataset

# %%
df.describe()
# Out:
#         Unnamed: 0
# count  1199.000000
# mean    149.602168
# std      86.601968
# min       0.000000
# 25%      75.000000
# 50%     150.000000
# 75%     224.500000
# max     299.000000

# %% [markdown]
# # information about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1199 entries, 0 to 1198
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1199 non-null   int64
#  1   label       1199 non-null   object
#  2   text        1199 non-null   object
# dtypes: int64(1), object(2)
# memory usage: 28.2+ KB

# %% [markdown]
# # checking the number of unique value

# %%
df.nunique()
# Out:
# Unnamed: 0     300
# label           24
# text          1152
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# label         0
# text          0
# dtype: int64

# %% [markdown]
# observatio:
#     there are no missing value

# %% [markdown]
# # check duplicate

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# observation:
#     there are no duplicate value

# %% [markdown]
# # convert categorical feature to numerical feature

# %%
df_copy=df.copy()

# %%
df_copy['label'].unique()
# Out:
# array(['Psoriasis', 'Varicose Veins', 'Typhoid', 'Chicken pox',
#        'Impetigo', 'Dengue', 'Fungal infection', 'Common Cold',
#        'Pneumonia', 'Dimorphic Hemorrhoids', 'Arthritis', 'Acne',
#        'Bronchial Asthma', 'Hypertension', 'Migraine',
#        'Cervical spondylosis', 'Jaundice', 'Malaria',
#        'urinary tract infection', 'allergy',
#        'gastroesophageal reflux disease', 'drug reaction',
#        'peptic ulcer disease', 'diabetes'], dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder
encoder=OneHotEncoder()

# %%
df
# Out:
#       Unnamed: 0      label                                               text
# 0              0  Psoriasis  I have been experiencing a skin rash on my arm...
# 1              1  Psoriasis  My skin has been peeling, especially on my kne...
# 2              2  Psoriasis  I have been experiencing joint pain in my fing...
# 3              3  Psoriasis  There is a silver like dusting on my skin, esp...
# 4              4  Psoriasis  My nails have small dents or pits in them, and...
# ...          ...        ...                                                ...
# 1194         295   diabetes  I'm shaking and trembling all over. I've lost ...
# 1195         296   diabetes  Particularly in the crevices of my skin, I hav...
# 1196         297   diabetes  I regularly experience these intense urges and...
# 1197         298   diabetes  I have trouble breathing, especially outside. ...
# 1198         299   diabetes  I constantly sneeze and have a dry cough. My i...
#
# [1199 rows x 3 columns]

# %%
df=pd.DataFrame({'label' :['Psoriasis', 'Varicose Veins', 'Typhoid', 'Chicken pox', 'Impetigo', 'Dengue', 'Fungal infection', 'Common Cold', 'Pneumonia', 'Dimorphic Hemorrhoids', 'Arthritis', 'Acne', 'Bronchial Asthma', 'Hypertension', 'Migraine', 'Cervical spondylosis', 'Jaundice', 'Malaria', 'urinary tract infection', 'allergy', 'gastroesophageal reflux disease', 'drug reaction', 'peptic ulcer disease', 'diabetes']})
df
# Out:
#                               label
# 0                         Psoriasis
# 1                    Varicose Veins
# 2                           Typhoid
# 3                       Chicken pox
# 4                          Impetigo
# 5                            Dengue
# 6                  Fungal infection
# 7                       Common Cold
# 8                         Pneumonia
# 9             Dimorphic Hemorrhoids
# 10                        Arthritis
# 11                             Acne
# 12                 Bronchial Asthma
# 13                     Hypertension
# 14                         Migraine
# 15             Cervical spondylosis
# 16                         Jaundice
# 17                          Malaria
# 18          urinary tract infection
# 19                          allergy
# 20  gastroesophageal reflux disease
# 21                    drug reaction
# 22             peptic ulcer disease
# 23                         diabetes

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize LabelEncoder
label_encoder = LabelEncoder()

label_encoder.fit_transform(df['label'])
# Out:
# array([15, 17, 16,  4, 10,  6,  8,  5, 14,  7,  1,  0,  2,  9, 13,  3, 11,
#        12, 23, 18, 21, 20, 22, 19])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   label   24 non-null     object
# dtypes: object(1)
# memory usage: 324.0+ bytes

# %%
 #df_copy['diesease']=df_copy['label'].astype('int')

# %%
 df_copy['label'].unique()
# Out:
# array(['Psoriasis', 'Varicose Veins', 'Typhoid', 'Chicken pox',
#        'Impetigo', 'Dengue', 'Fungal infection', 'Common Cold',
#        'Pneumonia', 'Dimorphic Hemorrhoids', 'Arthritis', 'Acne',
#        'Bronchial Asthma', 'Hypertension', 'Migraine',
#        'Cervical spondylosis', 'Jaundice', 'Malaria',
#        'urinary tract infection', 'allergy',
#        'gastroesophageal reflux disease', 'drug reaction',
#        'peptic ulcer disease', 'diabetes'], dtype=object)

# %%
categorical_columns = ['column1', 'column2', 'column3']  # Replace column1, column2, column3 with the actual names of your categorical columns
encoded_values = [15, 17, 16,  4, 10,  6,  8,  5, 14,  7,  1,  0,  2,  9, 13,  3, 11, 12, 23, 18, 21, 20, 22, 19]

# Update the categorical columns with the encoded values
for i, column in enumerate(categorical_columns):
    df[column] = encoded_values[i]

# %%
df
# Out:
#                               label  column1  column2  column3
# 0                         Psoriasis       15       17       16
# 1                    Varicose Veins       15       17       16
# 2                           Typhoid       15       17       16
# 3                       Chicken pox       15       17       16
# 4                          Impetigo       15       17       16
# 5                            Dengue       15       17       16
# 6                  Fungal infection       15       17       16
# 7                       Common Cold       15       17       16
# 8                         Pneumonia       15       17       16
# 9             Dimorphic Hemorrhoids       15       17       16
# 10                        Arthritis       15       17       16
# 11                             Acne       15       17       16
# 12                 Bronchial Asthma       15       17       16
# 13                     Hypertension       15       17       16
# ...

# %% [markdown]
# # OBSERVATION

# %% [markdown]
# # Bar Plot: To visualize the frequency of each label:

# %%
import matplotlib.pyplot as plt

# Assuming df is your DataFrame with label-encoded data
# Plotting bar plot for frequency of each label
plt.figure(figsize=(20, 6))
df['label'].value_counts().plot(kind='bar')
plt.title('Frequency of Each Label')
plt.xlabel('Labels')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# # Histogram: To visualize the distribution of encoded values for a specific feature (e.g., 'Psoriasis'):

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
data = {
    'label': ['Psoriasis', 'Varicose Veins', 'Typhoid', 'Chicken pox', 'Impetigo', 'Dengue', 'Fungal infection',
              'Common Cold', 'Pneumonia', 'Dimorphic Hemorrhoids', 'Arthritis', 'Acne', 'Bronchial Asthma',
              'Hypertension', 'Migraine', 'Cervical spondylosis', 'Jaundice', 'Malaria', 'urinary tract infection',
              'allergy', 'gastroesophageal reflux disease', 'drug reaction', 'peptic ulcer disease', 'diabetes'],
    'column1': [15] * 24,
    'column2': [17] * 24,
    'column3': [16] * 24
}

df = pd.DataFrame(data)

# Plot histograms for each column
for column in df.columns[1:]:
    plt.figure(figsize=(8, 6))
    plt.hist(df[column], bins=10, color='skyblue', edgecolor='black')
    plt.title(f'Histogram of {column}')
    plt.xlabel('Encoded Values')
    plt.ylabel('Frequency')
    plt.grid(True)
    plt.show()

# %%
print('Psoriasis' in df.columns)
# Out:
# False

# %% [markdown]
# # Scatter Plot: To visualize the relationship between two features (e.g., 'Psoriasis' and 'Varicose Veins'):

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Creating random numeric data associated with each label
np.random.seed(0)
numeric_data = np.random.randint(0, 100, size=len(df))

# Creating a DataFrame with label and numeric data
scatter_data = pd.DataFrame({'label': df['label'], 'numeric_data': numeric_data})

# Plotting a scatter plot
plt.figure(figsize=(10, 8))
plt.scatter(scatter_data['numeric_data'], df['column1'], color='blue', label='column1')
plt.scatter(scatter_data['numeric_data'], df['column2'], color='red', label='column2')
plt.scatter(scatter_data['numeric_data'], df['column3'], color='green', label='column3')
plt.title('Scatter Plot')
plt.xlabel('Numeric Data')
plt.ylabel('Encoded Values')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# # top 10 common disease

# %%
disease_frequency = df['label'].value_counts()
# Select top 10 common diseases
top_10_diseases = disease_frequency.head(10)

# Plot pie chart
plt.figure(figsize=(20, 15))
plt.pie(top_10_diseases, labels=top_10_diseases.index, autopct='%1.1f%%', startangle=140)
plt.title('Top 10 Common Diseases')
#plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# # HEATMAP

# %%
# Create a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 10})
plt.title('Correlation Heatmap')
plt.show()
# Out:
# C:\Users\PRAJES DAS\AppData\Local\Temp\ipykernel_4764\1514494573.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 10})
# C:\Users\PRAJES DAS\anaconda3\Lib\site-packages\seaborn\matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# C:\Users\PRAJES DAS\anaconda3\Lib\site-packages\seaborn\matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)

# %% [markdown]
# # Read the doctor dataset

# %%
import pandas as pd
df1=pd.read_csv("Disease_Doctor_Data.csv")
df1
# Out:
#       Doctor_Name         Specialist       Disease
# 0       Dr. Jones     ENT Specialist      Headache
# 1       Dr. Smith        Neurologist          Cold
# 2     Dr. Johnson        Neurologist         Fever
# 3    Dr. Williams  General Physician  Hypertension
# 4       Dr. Smith  General Physician   Stomachache
# ..            ...                ...           ...
# 195     Dr. Brown      Dermatologist   Stomachache
# 196   Dr. Johnson     ENT Specialist       Allergy
# 197  Dr. Williams        Neurologist          Cold
# 198   Dr. Johnson      Dermatologist       Allergy
# 199     Dr. Brown      Dermatologist         Fever
#
# [200 rows x 3 columns]

# %%
# SHAPE OF THE DATASET
df1.shape
# Out:
# (200, 3)

# %%
#details about this data
df1.describe()
# Out:
#        Doctor_Name    Specialist Disease
# count          200           200     200
# unique           5             5       9
# top      Dr. Smith  Cardiologist  Asthma
# freq            53            53      29

# %%
#information about this dataset
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Doctor_Name  200 non-null    object
#  1   Specialist   200 non-null    object
#  2   Disease      200 non-null    object
# dtypes: object(3)
# memory usage: 4.8+ KB

# %%
#unique data present into the dataset
df1.nunique()
# Out:
# Doctor_Name    5
# Specialist     5
# Disease        9
# dtype: int64

# %%
#checking null value is present in the dataset or not
df1.isnull().sum()
# Out:
# Doctor_Name    0
# Specialist     0
# Disease        0
# dtype: int64

# %%
#check how many data is duplicate in this dataset
df1.duplicated().sum()
# Out:
# 73

# %% [markdown]
# # converting categorical features into numerical features

# %%
df1_copy=df.copy()
df1
# Out:
#       Doctor_Name         Specialist       Disease
# 0       Dr. Jones     ENT Specialist      Headache
# 1       Dr. Smith        Neurologist          Cold
# 2     Dr. Johnson        Neurologist         Fever
# 3    Dr. Williams  General Physician  Hypertension
# 4       Dr. Smith  General Physician   Stomachache
# ..            ...                ...           ...
# 195     Dr. Brown      Dermatologist   Stomachache
# 196   Dr. Johnson     ENT Specialist       Allergy
# 197  Dr. Williams        Neurologist          Cold
# 198   Dr. Johnson      Dermatologist       Allergy
# 199     Dr. Brown      Dermatologist         Fever
#
# [200 rows x 3 columns]

# %%
 df1['Doctor_Name'].nunique()
# Out:
# 5

# %%
 df1['Specialist'].nunique()
# Out:
# 5

# %%
 df1['Disease'].nunique()
# Out:
# 9

# %%
df1
# Out:
#       Doctor_Name         Specialist       Disease
# 0       Dr. Jones     ENT Specialist      Headache
# 1       Dr. Smith        Neurologist          Cold
# 2     Dr. Johnson        Neurologist         Fever
# 3    Dr. Williams  General Physician  Hypertension
# 4       Dr. Smith  General Physician   Stomachache
# ..            ...                ...           ...
# 195     Dr. Brown      Dermatologist   Stomachache
# 196   Dr. Johnson     ENT Specialist       Allergy
# 197  Dr. Williams        Neurologist          Cold
# 198   Dr. Johnson      Dermatologist       Allergy
# 199     Dr. Brown      Dermatologist         Fever
#
# [200 rows x 3 columns]

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Load the doctor dataset
df = pd.DataFrame({
    'Doctor_Name': ['Dr. Jones', 'Dr. Smith', 'Dr. Johnson', 'Dr. Williams', 'Dr. Smith', 'Dr. Brown', 'Dr. Johnson', 'Dr. Williams', 'Dr. Johnson', 'Dr. Brown'],
    'Specialist': ['ENT Specialist', 'Neurologist', 'Neurologist', 'General Physician', 'General Physician', 'Dermatologist', 'ENT Specialist', 'Neurologist', 'Dermatologist', 'Dermatologist'],
    'Disease': ['Headache', 'Cold', 'Fever', 'Hypertension', 'Stomachache', 'Stomachache', 'Allergy', 'Cold', 'Allergy', 'Fever']
})

# Initialize LabelEncoder
label_encoder = LabelEncoder()

# Encode categorical features
df['Doctor_Name'] = label_encoder.fit_transform(df['Doctor_Name'])
df['Specialist'] = label_encoder.fit_transform(df['Specialist'])
df['Disease'] = label_encoder.fit_transform(df['Disease'])

# Display the numerical dataset
df
# Out:
#    Doctor_Name  Specialist  Disease
# 0            2           1        3
# 1            3           3        1
# 2            1           3        2
# 3            4           2        4
# 4            3           2        5
# 5            0           0        5
# 6            1           1        0
# 7            4           3        1
# 8            1           0        0
# 9            0           0        2

# %%
df
# Out:
#    Doctor_Name  Specialist  Disease
# 0            2           1        3
# 1            3           3        1
# 2            1           3        2
# 3            4           2        4
# 4            3           2        5
# 5            0           0        5
# 6            1           1        0
# 7            4           3        1
# 8            1           0        0
# 9            0           0        2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Doctor_Name  10 non-null     int64
#  1   Specialist   10 non-null     int64
#  2   Disease      10 non-null     int64
# dtypes: int64(3)
# memory usage: 372.0 bytes

# %% [markdown]
# # data visualization

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Sample doctor dataset
data = {
    'Doctor_Name': ['Dr. Jones', 'Dr. Smith', 'Dr. Johnson', 'Dr. Williams', 'Dr. Smith', 'Dr. Brown', 'Dr. Johnson', 'Dr. Williams', 'Dr. Johnson', 'Dr. Brown'],
    'Specialist': ['ENT Specialist', 'Neurologist', 'Neurologist', 'General Physician', 'General Physician', 'Dermatologist', 'ENT Specialist', 'Neurologist', 'Dermatologist', 'Dermatologist'],
    'Disease': ['Headache', 'Cold', 'Fever', 'Hypertension', 'Stomachache', 'Stomachache', 'Allergy', 'Cold', 'Allergy', 'Fever']
}

# Create DataFrame
df = pd.DataFrame(data)
df
# Out:
#     Doctor_Name         Specialist       Disease
# 0     Dr. Jones     ENT Specialist      Headache
# 1     Dr. Smith        Neurologist          Cold
# 2   Dr. Johnson        Neurologist         Fever
# 3  Dr. Williams  General Physician  Hypertension
# 4     Dr. Smith  General Physician   Stomachache
# 5     Dr. Brown      Dermatologist   Stomachache
# 6   Dr. Johnson     ENT Specialist       Allergy
# 7  Dr. Williams        Neurologist          Cold
# 8   Dr. Johnson      Dermatologist       Allergy
# 9     Dr. Brown      Dermatologist         Fever

# %%
# Bar plot for Doctor Name
plt.figure(figsize=(10, 6))
sns.countplot(x='Doctor_Name', data=df)
plt.title('Frequency of Doctors')
plt.xlabel('Doctor Name')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
# Pie plot for Disease
plt.figure(figsize=(8, 8))
df['Disease'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Diseases')
plt.axis('equal')
plt.show()

# %%
# Histogram for Specialist
plt.figure(figsize=(8, 6))
sns.histplot(data=df, x='Specialist', bins=len(df['Specialist'].unique()), kde=True)
plt.title('Distribution of Specialists')
plt.xlabel('Specialist')
plt.ylabel('Frequency')
plt.show()

# %%
# Scatter plot between Doctor Name and Disease
plt.figure(figsize=(8, 6))
sns.scatterplot(data=df, x='Doctor_Name', y='Disease')
plt.title('Scatter Plot of Doctor Name vs. Disease')
plt.xlabel('Doctor Name')
plt.ylabel('Disease')
plt.show()

# %% [markdown]
# # HEATMAP

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Creating DataFrame from provided data
data = {
    'Doctor_Name': [2, 3, 1, 4, 3, 0, 1, 4, 1, 0],
    'Specialist': [1, 3, 3, 2, 2, 0, 1, 3, 0, 0],
    'Disease': [3, 1, 2, 4, 5, 5, 0, 1, 0, 2]
}

df = pd.DataFrame(data)

# Create heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt=".2f", annot_kws={"size": 10})
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# # CHATBOT IMPLEMENTATION

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline

data = pd.read_csv("C:\\Users\\PRAJES DAS\\Downloads\\Symptom2Disease.csv")

X = data['text']
Y = data['label']

model = make_pipeline(CountVectorizer(), MultinomialNB())
model.fit(X, Y)

doctor_data = pd.read_csv("Disease_Doctor_Data.csv")

# Function to detect diseases
def get_disease_detection(symptoms):
    predicted_disease = model.predict([symptoms])[0]
    return predicted_disease

def get_doctor_suggestion(disease):
    matching_doctors = doctor_data.loc[doctor_data['Disease'] == disease]
    if not matching_doctors.empty:
        doctor_info = matching_doctors.sample(1)  # Randomly select one doctor from matching list
        specialist = doctor_info['Specialist'].values[0]
        doctor_name = doctor_info['Doctor_Name'].values[0]
    else:
        specialist = "General Physician"
        doctor_name = "Dr. Thomas Jerry Ciolino"
    return specialist, doctor_name

def chat():
    print(".............Welcome To Disease Detection Chatbot!.............")
    print("Chatbot: Hi there! What's your name?")
    name = input("You: ")

    print("Chatbot: Hello, " + name + "! How can I assist you today?(enter symptoms that you have)")

    symptoms = ""
    while True:
        user_input = input("You: ")

        if user_input.lower() in ['quit', 'exit', 'bye', 'thank you', 'no']:
            print("Chatbot: Goodbye!")
            break
        elif user_input.strip() == '':
            print("Chatbot: It seems like you have no query. Goodbye!")
            break
        else:
            if symptoms == "":
                symptoms = user_input
            else:
                symptoms += ", " + user_input

            print("Chatbot: How many days have you been experiencing these symptoms?")
            days = input("You: ")

            print("Chatbot: Do you have any other symptoms or concerns you'd like to share? (yes/no)")
            response = input("You: ")

            if response.lower() == 'no':
                predicted_disease = get_disease_detection(symptoms)
                print("Chatbot: It seems like you might have", predicted_disease)

                specialist, doctor_name = get_doctor_suggestion(predicted_disease)
                print(f"Chatbot: I recommend you to consult a {specialist}. You can consult {doctor_name}.")
                print("Chatbot: Okay, if you have any more questions or concerns, feel free to ask!")
                break

            elif response.lower() == 'yes':
                continue
            else:
                print("Chatbot: I'm sorry, I didn't understand that. Please respond with 'yes' or 'no'.")

chat()
# Out:
# .............Welcome To Disease Detection Chatbot!.............
# Chatbot: Hi there! What's your name?
# You: prajes
# Chatbot: Hello, prajes! How can I assist you today?(enter symptoms that you have)
# You: i have high body temparature
# Chatbot: How many days have you been experiencing these symptoms?
# You: 3
# Chatbot: Do you have any other symptoms or concerns you'd like to share? (yes/no)
# You: yes
# You: pain in head
# Chatbot: How many days have you been experiencing these symptoms?
# You: 2
# Chatbot: Do you have any other symptoms or concerns you'd like to share? (yes/no)
# You: yes
# You: too much body pain
# Chatbot: How many days have you been experiencing these symptoms?
# You: 2
# Chatbot: Do you have any other symptoms or concerns you'd like to share? (yes/no)
# You: no
# Chatbot: It seems like you might have Dengue
# Chatbot: I recommend you to consult a General Physician. You can consult Dr. Thomas Jerry Ciolino.
# ...

# %% [markdown]
# # accuracy

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)


model.fit(X_train, Y_train)

Y_pred = model.predict(X_test)

accuracy = accuracy_score(Y_test, Y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.95

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score


X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)


model.fit(X_train, Y_train)

Y_pred = model.predict(X_test)

# Sample data
X_train = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)  # Sample features
Y_train = np.array([2, 4, 5, 4, 5])  # Sample target

# Initialize and fit linear regression model
regression_model = LinearRegression()
regression_model.fit(X_train, Y_train)

# Make predictions
Y_pred = regression_model.predict(X_train)

# Calculate R-squared score
r_squared = r2_score(Y_train, Y_pred)

# Calculate adjusted R-squared score
n = len(Y_train)  # Number of observations
p = X_train.shape[1]  # Number of features
adjusted_r_squared = 1 - (1 - r_squared) * (n - 1) / (n - p - 1)

print("R-squared:", r_squared)
print("Adjusted R-squared:", adjusted_r_squared)
# Out:
# R-squared: 0.6000000000000001
# Adjusted R-squared: 0.4666666666666668

# %% [markdown]
# Observation:
#     in this ml model health care chatbot . when we input some symptons in output section we get the dtails about the diesease
#     ,doctor suggestion ,we add additional symptons in any language we have converstion with the chatbot.
